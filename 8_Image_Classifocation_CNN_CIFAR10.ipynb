# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# Load and preprocess CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define the CNN model architecture
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# Add Dense layers on top for classification
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))  # 10 classes in CIFAR-10, no activation (for logits)

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Display the model summary
model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122570 (478.79 KB)
# Trainable params: 122570 (478.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 19s 5ms/step - loss: 1.5425 - accuracy: 0.4364 - val_loss: 1.2747 - val_accuracy: 0.5414
# Epoch 2/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1856 - accuracy: 0.5802 - val_loss: 1.1669 - val_accuracy: 0.5812
# Epoch 3/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0291 - accuracy: 0.6395 - val_loss: 1.0172 - val_accuracy: 0.6439
# Epoch 4/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9261 - accuracy: 0.6746 - val_loss: 0.9744 - val_accuracy: 0.6540
# Epoch 5/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8549 - accuracy: 0.7005 - val_loss: 0.8896 - val_accuracy: 0.6825
# Epoch 6/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7993 - accuracy: 0.7193 - val_loss: 0.9040 - val_accuracy: 0.6871
# Epoch 7/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7447 - accuracy: 0.7390 - val_loss: 0.9658 - val_accuracy: 0.6677
# Epoch 8/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6998 - accuracy: 0.7534 - val_loss: 0.8736 - val_accuracy: 0.6980
# Epoch 9/10
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.6606 - accuracy: 0.7659 - val_loss: 0.9398 - val_accuracy: 0.6813
# Epoch 10/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.6254 - accuracy: 0.7790 - val_loss: 0.8822 - val_accuracy: 0.7023
# 313/313 [==============================] - 1s 3ms/step - loss: 0.8822 - accuracy: 0.7023
# Test accuracy: 0.7023000121116638

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Load the trained model
# model = tf.keras.models.load_model('path_to_your_saved_model')  # Replace with the path to your saved model

# Define a function to preprocess the input image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(32, 32))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return img_array / 255.0  # Normalize pixel values

# Define a function to predict the class of the input image
def classify_image(image_path):
    processed_img = preprocess_image(image_path)
    prediction = model.predict(processed_img)
    predicted_class = np.argmax(prediction)
    return predicted_class

# CIFAR-10 classes
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Replace 'path_to_your_image' with the path to the image you want to classify
image_path = '/content/plane.webp'
predicted_class = classify_image(image_path)

# Display the image
img = image.load_img(image_path, target_size=(32, 32))
plt.imshow(img)
plt.axis('off')
plt.title(f'Predicted Class: {class_names[predicted_class]}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
